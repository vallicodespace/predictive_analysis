# %% [markdown]
# # Predictive Analysis Model Comparison
#
# Run these cells in Google Colab to install dependencies, execute the Python script, and review the model results.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Update the folder path below if the project folder is saved under a different Google Drive location.

# %%
# %cd /content/drive/MyDrive/New project

# %%
# !pip install -r requirements.txt

# %%
# !python predictive_analysis.py --data data/iot_sensor_energy.csv --output outputs

# %%
import pandas as pd
results = pd.read_csv('outputs/model_results.csv')
results

# %%
from IPython.display import Image, display
display(Image(filename='outputs/model_rmse_comparison.png'))
display(Image(filename='outputs/actual_vs_predicted_best_model.png'))
