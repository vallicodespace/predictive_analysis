# %% [markdown]
# # predictive_analysis
#
# Use these cells in Google Colab to upload the project zip, install the required libraries, run the script, and review the results.

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# Upload `predictive_analysis.zip`, unzip it, and move into the project folder before running the script.

# %%
# !unzip -o predictive_analysis.zip
# %cd predictive_analysis

# %%
# !pip install -r requirements.txt

# %%
# !python predictive_analysis.py --data data/iot_sensor_energy.csv --output outputs

# %%
import pandas as pd
results = pd.read_csv('outputs/model_results.csv')
results

# %%
from IPython.display import Image, display
display(Image(filename='outputs/model_rmse_comparison.png'))
display(Image(filename='outputs/actual_vs_predicted_best_model.png'))
